# %%
import pandas as pd
info= pd.DataFrame({"P":[4,7,1,8,9],
                    "Q":[6,8,10,15,11],
                    "R":[17,13,12,16,14],
                    "S":[15,19,7,21,9]},
                  index = ["Neha","Pragati","Punam","Priyanshu","Shruti"])
info
# Out:
#            P   Q   R   S
# Neha       4   6  17  15
# Pragati    7   8  13  19
# Punam      1  10  12   7
# Priyanshu  8  15  16  21
# Shruti     9  11  14   9

# %%
from matplotlib import pyplot as plt

x = [9.5, 5, 8, 4, 2]

y = [5, 2, 9, 4, 7]

plt.bar(x, y)

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

cars = ['AUDI', 'BMW', 'FORD',
		'TESLA', 'JAGUAR', 'MERCEDES']

data = [23, 17, 35, 29, 12, 41]

fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)

plt.show()
